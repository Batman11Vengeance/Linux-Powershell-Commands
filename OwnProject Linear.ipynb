# %%
# ------------------------------
# INDUSTRIAL INCIDENT ANALYSIS
# LINEAR REGRESSION MODEL
# ------------------------------

# Import Libraries
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score


# ------------------------------
# LOAD DATASET
# ------------------------------

# Replace with your actual file name
df = pd.read_excel("industrial_incident_reports (1).xlsx")

# Display first 5 rows
print("FIRST 5 ROWS:\n")
print(df.head())

# Display column names
print("\nCOLUMN NAMES:\n")
print(df.columns)


# ------------------------------
# SELECT INPUT FEATURES (X)
# ------------------------------

X = df[[
    'Severity (Numeric)\n1=Near Miss … 5=Critical',
    'Category (Numeric)\nSee legend',
    'Department (Numeric)\nSee legend',
    'Injuries',
    'Month (1–12)',
    'Day of Week\n1=Mon … 7=Sun'
]]


# ------------------------------
# SELECT TARGET VARIABLE (Y)
# ------------------------------

Y = df['Lost Time Days']


# ------------------------------
# SPLIT DATASET
# ------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)


# ------------------------------
# CREATE MODEL
# ------------------------------

model = LinearRegression()


# ------------------------------
# TRAIN MODEL
# ------------------------------

model.fit(X_train, y_train)

print("\nMODEL TRAINED SUCCESSFULLY")


# ------------------------------
# MAKE PREDICTIONS
# ------------------------------

y_pred = model.predict(X_test)


# ------------------------------
# EVALUATE MODEL
# ------------------------------

mae = mean_absolute_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

print("\nMODEL EVALUATION")
print("---------------------")

print("Mean Absolute Error:", mae)

print("R2 Score:", r2)


# ------------------------------
# SHOW ACTUAL VS PREDICTED
# ------------------------------

results = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print("\nACTUAL VS PREDICTED:\n")

print(results.head(10))


# ------------------------------
# USER INPUT PREDICTION
# ------------------------------

print("\nENTER INCIDENT DETAILS")

severity = float(input("Severity (Numeric): "))
category = float(input("Category (Numeric): "))
department = float(input("Department (Numeric): "))
injuries = float(input("Number of Injuries: "))
month = float(input("Month: "))
day = float(input("Day of Week: "))

sample_data = [[
    severity,
    category,
    department,
    injuries,
    month,
    day
]]

prediction = model.predict(sample_data)

print("\nPREDICTED LOST TIME DAYS:")

print(prediction[0])
# Out:
# FIRST 5 ROWS:
#
#   Incident ID        Date   Time           Category   Severity  \
# 0    INC-0061  2023-01-30  15:54   Fall from Height  Near Miss
# 1    INC-0096  2023-02-04  18:23  Vehicle/Transport        Low
# 2    INC-0037  2023-02-09  03:38  Toxic Gas Release     Medium
# 3    INC-0045  2023-02-21  17:15   Ergonomic Injury   Critical
# 4    INC-0008  2023-03-09  06:58  Equipment Failure        Low
#
#             Department         Location  \
# 0  Chemical Processing    Cooling Tower
# 1            Warehouse   Mixing Chamber
# 2      Refinery Unit A   Rooftop Access
# 3          Maintenance  Pipe Corridor 3
# 4      Refinery Unit A     Control Room
#
#                                          Description              Root Cause  \
# 0  Safety harness not attached; worker slipped ne...     Unauthorized access
# 1  Forklift clipped shelving unit; load toppled b...      Improper PPE usage
# 2  Chlorine leak from cylinder valve triggered SC...  Procedure not followed
# ...
